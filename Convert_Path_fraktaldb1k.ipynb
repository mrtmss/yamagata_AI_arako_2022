# %%
#ライブラリをインポート
#標準ライブラリ
import os
import shutil
from pathlib import Path

# %% [markdown]
# # 概要

# %% [markdown]
# fraktalDB-1kのパスを変換する

# %%
rename_output_path___ = 'after_740'

# %%
for i, path in enumerate(list_fraktal_path[740:]):
    os.rename(path, os.path.join(rename_output_path___, fraktal_path[-5:] + '_' + str(i) + ".jpg"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 for i, path in enumerate(list_fraktal_path[740:]):
#       2     os.rename(path, os.path.join(rename_output_path___, fraktal_path[-5:] + '_' + str(i) + ".jpg"))
#
# NameError: name 'list_fraktal_path' is not defined

# %%
list(Path().iterdir())
# Out:
# [WindowsPath('.git'),
#  WindowsPath('.ipynb_checkpoints'),
#  WindowsPath('01_ConvBatchNormReLUMaxPoolDropout_FCFC.ipynb'),
#  WindowsPath('02_ConvBatchNormReLUMaxPoolDropout_FCDropoutFC.ipynb'),
#  WindowsPath('03_ConvBatchNormReLUMaxPoolDropout_GlovalAvg.ipynb'),
#  WindowsPath('04_DepthwiseSeparableConvBatchNormReLUMaxPoolDropout_FCFC.ipynb'),
#  WindowsPath('05_DepthwiseSeparableConvBatchNormReLUMaxPoolDropout_FCDropoutFC.ipynb'),
#  WindowsPath('06_DepthwiseSeparableConvBatchNormReLUMaxPoolDropout_GlovalAvg.ipynb'),
#  WindowsPath('07_ConvBatchNormReLUMaxPoolDropoutPPM_FCFC.ipynb'),
#  WindowsPath('08_ConvBatchNormReLUMaxPoolDropoutPPM_FCDropoutFC.ipynb'),
#  WindowsPath('09_ConvBatchNormReLUMaxPoolDropoutPPM_GlovalAvg.ipynb'),
#  WindowsPath('10_ConvBatchNormReLUMaxPoolDropoutSEModile_FCFC.ipynb'),
#  WindowsPath('11_ConvBatchNormReLUMaxPoolDropoutSEModule_FCDropoutFC.ipynb'),
#  WindowsPath('12_ConvBatchNormReLUMaxPoolDropoutSEModule_GlovalAvg.ipynb'),
# ...

# %%
1000*100
# Out:
# 100000

# %%
for fraktal_path in list(Path('fraktalDB-1k_rename').iterdir())[80000:]:
    fraktal_path = str(fraktal_path)
    shutil.move(fraktal_path, rename_output_path___)
    #os.path.join(rename_output_path___, fraktal_path)

# %%
list_fraktal_path[739:]
# Out:
# ['FractalDB-1k\\00739',
#  'FractalDB-1k\\00740',
#  'FractalDB-1k\\00741',
#  'FractalDB-1k\\00742',
#  'FractalDB-1k\\00743',
#  'FractalDB-1k\\00744',
#  'FractalDB-1k\\00745',
#  'FractalDB-1k\\00746',
#  'FractalDB-1k\\00747',
#  'FractalDB-1k\\00748',
#  'FractalDB-1k\\00749',
#  'FractalDB-1k\\00750',
#  'FractalDB-1k\\00751',
#  'FractalDB-1k\\00752',
#  'FractalDB-1k\\00753',
#  'FractalDB-1k\\00754',
#  'FractalDB-1k\\00755',
#  'FractalDB-1k\\00756',
#  'FractalDB-1k\\00757',
#  'FractalDB-1k\\00758',
#  'FractalDB-1k\\00759',
#  'FractalDB-1k\\00760',
#  'FractalDB-1k\\00761',
#  'FractalDB-1k\\00762',
#  'FractalDB-1k\\00763',
#  'FractalDB-1k\\00764',
#  'FractalDB-1k\\00765',
#  'FractalDB-1k\\00766',
#  'FractalDB-1k\\00767',
#  'FractalDB-1k\\00768',
#  'FractalDB-1k\\00769',
#  'FractalDB-1k\\00770',
#  'FractalDB-1k\\00771',
#  'FractalDB-1k\\00772',
#  'FractalDB-1k\\00773',
#  'FractalDB-1k\\00774',
#  'FractalDB-1k\\00775',
#  'FractalDB-1k\\00776',
# ...

# %% [markdown]
# # 対象となるディレクトリのロード

# %%
#fraktal_pathのリスト
list_fraktal_path = list(Path('FractalDB-1k').iterdir())

#str化
list_fraktal_path = [str(path) for path in list_fraktal_path]

# %%
len(list_fraktal_path)
# Out:
# 1000

# %% [markdown]
# # リネームし、あるフォルダへ吐き出す

# %%
rename_output_path = 'fraktalDB-1k_rename'

# %%
for fraktal_path in list_fraktal_path:
    identifi_path = list(Path(fraktal_path).iterdir())
    #str化
    identifi_path = [str(path) for path in identifi_path]
    for i, path in enumerate(identifi_path):
        os.rename(path, os.path.join(rename_output_path, fraktal_path[-5:] + '_' + str(i) + ".jpg"))

# %%
for i in range(999):
    print(f'$Location$ LIKE "*{i:05}*" => "{i:05}"')
# Out:
# $Location$ LIKE "*00000*" => "00000"
# $Location$ LIKE "*00001*" => "00001"
# $Location$ LIKE "*00002*" => "00002"
# $Location$ LIKE "*00003*" => "00003"
# $Location$ LIKE "*00004*" => "00004"
# $Location$ LIKE "*00005*" => "00005"
# $Location$ LIKE "*00006*" => "00006"
# $Location$ LIKE "*00007*" => "00007"
# $Location$ LIKE "*00008*" => "00008"
# $Location$ LIKE "*00009*" => "00009"
# $Location$ LIKE "*00010*" => "00010"
# $Location$ LIKE "*00011*" => "00011"
# $Location$ LIKE "*00012*" => "00012"
# $Location$ LIKE "*00013*" => "00013"
# $Location$ LIKE "*00014*" => "00014"
# $Location$ LIKE "*00015*" => "00015"
# $Location$ LIKE "*00016*" => "00016"
# $Location$ LIKE "*00017*" => "00017"
# $Location$ LIKE "*00018*" => "00018"
# $Location$ LIKE "*00019*" => "00019"
# $Location$ LIKE "*00020*" => "00020"
# $Location$ LIKE "*00021*" => "00021"
# $Location$ LIKE "*00022*" => "00022"
# $Location$ LIKE "*00023*" => "00023"
# $Location$ LIKE "*00024*" => "00024"
# ...

# %%
999/3
# Out:
# 333.0

# %%
1000/10
# Out:
# 100.0

# %%
for i in range(30, 999):
    print(f'{i:05}')
# Out:
# 00030
# 00031
# 00032
# 00033
# 00034
# 00035
# 00036
# 00037
# 00038
# 00039
# 00040
# 00041
# 00042
# 00043
# 00044
# 00045
# 00046
# 00047
# 00048
# 00049
# 00050
# 00051
# 00052
# 00053
# 00054
# 00055
# 00056
# 00057
# 00058
# 00059
# 00060
# 00061
# 00062
# 00063
# 00064
# 00065
# 00066
# 00067
# 00068
# 00069
# 00070
# 00071
# 00072
# 00073
# 00074
# 00075
# 00076
# 00077
# 00078
# 00079
# 00080
# 00081
# 00082
# 00083
# 00084
# 00085
# 00086
# 00087
# 00088
# 00089
# 00090
# 00091
# 00092
# 00093
# 00094
# 00095
# 00096
# 00097
# 00098
# 00099
# 00100
# 00101
# 00102
# 00103
# 00104
# 00105
# 00106
# 00107
# 00108
# 00109
# 00110
# 00111
# 00112
# 00113
# 00114
# 00115
# 00116
# 00117
# 00118
# 00119
# 00120
# 00121
# 00122
# 00123
# 00124
# 00125
# 00126
# 00127
# 00128
# 00129
# 00130
# 00131
# 00132
# 00133
# 00134
# 00135
# 00136
# 00137
# 00138
# 00139
# 00140
# 00141
# 00142
# 00143
# 00144
# 00145
# 00146
# 00147
# 00148
# 00149
# 00150
# 00151
# 00152
# 00153
# 00154
# ...
